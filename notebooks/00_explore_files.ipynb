# %%
import pandas as pd

# %%
def describe_df(df):
    return pd.DataFrame([[col, len(set(df[col])),] for col in list(df.columns)], columns= ['column', 'unique_elements', ],)

# %%
compounds = pd.read_csv('../data/compounds_all_new.csv')
model = pd.read_csv('../data/model_algorithm_added.csv')
nms = pd.read_csv('../data/nanomaterials_final_df.csv')

# %%
compounds.head(5)
# Out:
#      CID MolecularFormula                              CanonicalSMILES  \
# 0   9845           C4F6O3                C(=O)(C(F)(F)F)OC(=O)C(F)(F)F
# 1  76074        C4Cl2F4O3              C(=O)(C(F)(F)Cl)OC(=O)C(F)(F)Cl
# 2  67742          C6F10O3  C(=O)(C(C(F)(F)F)(F)F)OC(=O)C(C(F)(F)F)(F)F
# 3  87067           C6H8O3                            CC1(CC(=O)OC1=O)C
# 4   7923           C4H2O3                               C1=CC(=O)OC1=O
#
#                                                InChI  \
# 0     InChI=1S/C4F6O3/c5-3(6,7)1(11)13-2(12)4(8,9)10
# 1  InChI=1S/C4Cl2F4O3/c5-3(7,8)1(11)13-2(12)4(6,9)10
# 2  InChI=1S/C6F10O3/c7-3(8,5(11,12)13)1(17)19-2(1...
# 3    InChI=1S/C6H8O3/c1-6(2)3-4(7)9-5(6)8/h3H2,1-2H3
# 4             InChI=1S/C4H2O3/c5-3-1-2-4(6)7-3/h1-2H
#
#                       InChIKey  \
# 0  QAEDZJGFFMLHHQ-UHFFFAOYSA-N
# 1  VBJIFLOSOQGDRZ-UHFFFAOYSA-N
# 2  XETRHNFRKCNWAJ-UHFFFAOYSA-N
# 3  ACJPFLIEHGFXGP-UHFFFAOYSA-N
# 4  FPYJFEHAWHCUMM-UHFFFAOYSA-N
#
# ...

# %%
model.head(5)
# Out:
#    Unnamed: 0 Ref                                         Model name  \
# 0           0  1a  Prediction model of nanoparticles uptake by Pa...
# 1           1  1b  Prediction model of nanoparticles uptake by Pa...
# 2           2  2a  Methodology for developing structure-activity ...
# 3           3  2b  Methodology for developing structure-activity ...
# 4           4  3a  Biological activity of manufactured nanopartic...
#
#        Contact person Contact person email address  \
# 0  Mehdi Ghorbanzadeh      m.ghorbanzade@umz.ac.ir
# 1  Mehdi Ghorbanzadeh      m.ghorbanzade@umz.ac.ir
# 2      Christie Sayes          csayes@cvm.tamu.edu
# 3      Christie Sayes          csayes@cvm.tamu.edu
# 4   Alexander Tropsha         alex_tropsha@unc.edu
#
#                                              Authors  Year  \
# 0        M. Ghorbanzadeh; M. H. Fatemi; M. Karimpour  2012
# 1        M. Ghorbanzadeh; M. H. Fatemi; M. Karimpour  2012
# ...

# %%
nms.head(5)
# Out:
#        CID MolecularFormula         IsomericSMILES  \
# 0    934.0             Ni+2                 [Ni+2]
# 1    935.0               Ni                   [Ni]
# 2   9863.0              CSi             [C-]#[Si+]
# 3  14769.0            Al2O3          O=[Al]O[Al]=O
# 4  14771.0            As2O5  O=[As](=O)O[As](=O)=O
#
#                            InChI                     InChIKey  \
# 0                InChI=1S/Ni/q+2  VEQPNABPJHWNSG-UHFFFAOYSA-N
# 1                    InChI=1S/Ni  PXHVJJICTQNCMI-UHFFFAOYSA-N
# 2              InChI=1S/CSi/c1-2  HBMJWWWQQXIZIP-UHFFFAOYSA-N
# 3                InChI=1S/2Al.3O  TWNQGVIAIRXVLR-UHFFFAOYSA-N
# 4  InChI=1S/As2O5/c3-1(4)7-2(5)6  COHDHYZHOPQOFD-UHFFFAOYSA-N
#
#                     IUPACName nm_unique
# 0                  nickel(2+)        Ni
# 1                      nickel        Ni
# 2   methanidylidynesilanylium       SiC
# 3  oxo(oxoalumanyloxy)alumane     Al2O3
# 4                         NaN     As2O5

# %%
describe_df(compounds)
# Out:
#              column  unique_elements
# 0               CID              176
# 1  MolecularFormula              154
# 2   CanonicalSMILES              173
# 3             InChI              176
# 4          InChIKey              176
# 5         IUPACName              176
# 6         nm_unique              274

# %%
describe_df(model)
# Out:
#                                                column  unique_elements
# 0                                          Unnamed: 0              204
# 1                                                 Ref              204
# 2                                          Model name              201
# 3                                      Contact person               57
# 4                        Contact person email address               57
# 5                                             Authors               82
# 6                                                Year               14
# 7                                               Title               87
# 8                                             Journal               48
# 9                                                 DOI               88
# 10                                          QSAR/QSPR                2
# 11                                   General type NMs                7
# ...

# %%
describe_df(nms)
# Out:
#              column  unique_elements
# 0               CID              640
# 1  MolecularFormula              208
# 2    IsomericSMILES              625
# 3             InChI              614
# 4          InChIKey              614
# 5         IUPACName              591
# 6         nm_unique              113
